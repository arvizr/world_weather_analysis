# %%
import citipy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import citipy
#
# ModuleNotFoundError: No module named 'citipy'

# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import random

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
np =  lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 767

# %%
#Import dependencies
import requests
weather_api_key = "ae77f417083173c4076216fc9ae2009b"

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | thompson
# Processing Record 2 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 1 | huilong
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | pacific grove
# Processing Record 6 of Set 1 | elko
# Processing Record 7 of Set 1 | owando
# Processing Record 8 of Set 1 | jadu
# Processing Record 9 of Set 1 | fort nelson
# Processing Record 10 of Set 1 | ponta do sol
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | darovskoy
# Processing Record 13 of Set 1 | hilo
# Processing Record 14 of Set 1 | chicama
# Processing Record 15 of Set 1 | zhezkazgan
# Processing Record 16 of Set 1 | vostok
# Processing Record 17 of Set 1 | tarko-sale
# Processing Record 18 of Set 1 | cherskiy
# Processing Record 19 of Set 1 | norman wells
# Processing Record 20 of Set 1 | tashtyp
# Processing Record 21 of Set 1 | trincomalee
# Processing Record 22 of Set 1 | tadine
# Processing Record 23 of Set 1 | mizoch
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | dores do indaia
# Processing Record 26 of Set 1 | darhan
# Processing Record 27 of Set 1 | kodinsk
# Processing Record 28 of Set 1 | alofi
# Processing Record 29 of Set 1 | luderitz
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | lorengau
# Processing Record 32 of Set 1 | dingle
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | atuona
# Processing Record 35 of Set 1 | santiago del estero
# Processing Record 36 of Set 1 | saint-philippe
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | guelengdeng
# City not found. Skipping...
# Processing Record 40 of Set 1 | bethel
# Processing Record 41 of Set 1 | ossora
# Processing Record 42 of Set 1 | najran
# Processing Record 43 of Set 1 | new norfolk
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | esperance
# Processing Record 47 of Set 1 | jamestown
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | guerrero negro
# Processing Record 1 of Set 2 | grand-santi
# Processing Record 2 of Set 2 | khatanga
# Processing Record 3 of Set 2 | port elizabeth
# Processing Record 4 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 2 | miandrivazo
# Processing Record 6 of Set 2 | sitka
# Processing Record 7 of Set 2 | chokurdakh
# Processing Record 8 of Set 2 | devyatka
# City not found. Skipping...
# Processing Record 9 of Set 2 | salalah
# Processing Record 10 of Set 2 | palmer
# Processing Record 11 of Set 2 | vaini
# Processing Record 12 of Set 2 | qaanaaq
# Processing Record 13 of Set 2 | poum
# Processing Record 14 of Set 2 | harper
# Processing Record 15 of Set 2 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 16 of Set 2 | rawson
# Processing Record 17 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 2 | hobart
# Processing Record 19 of Set 2 | oktyabrskoye
# Processing Record 20 of Set 2 | tubruq
# City not found. Skipping...
# Processing Record 21 of Set 2 | yerbogachen
# Processing Record 22 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 2 | carnarvon
# Processing Record 24 of Set 2 | puerto ayora
# Processing Record 25 of Set 2 | nikolskoye
# Processing Record 26 of Set 2 | bluff
# Processing Record 27 of Set 2 | tawau
# Processing Record 28 of Set 2 | yar-sale
# Processing Record 29 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 2 | lompoc
# Processing Record 32 of Set 2 | mayo
# Processing Record 33 of Set 2 | frontera
# Processing Record 34 of Set 2 | dikson
# Processing Record 35 of Set 2 | hithadhoo
# Processing Record 36 of Set 2 | kodiak
# Processing Record 37 of Set 2 | constitucion
# Processing Record 38 of Set 2 | ostrovnoy
# Processing Record 39 of Set 2 | matay
# Processing Record 40 of Set 2 | mitsamiouli
# Processing Record 41 of Set 2 | harrison
# Processing Record 42 of Set 2 | talnakh
# Processing Record 43 of Set 2 | pouembout
# Processing Record 44 of Set 2 | mentok
# City not found. Skipping...
# Processing Record 45 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 2 | necochea
# Processing Record 47 of Set 2 | tasiilaq
# Processing Record 48 of Set 2 | tuktoyaktuk
# Processing Record 49 of Set 2 | mount gambier
# Processing Record 50 of Set 2 | iqaluit
# Processing Record 1 of Set 3 | port alfred
# Processing Record 2 of Set 3 | upernavik
# Processing Record 3 of Set 3 | berlevag
# Processing Record 4 of Set 3 | grindavik
# Processing Record 5 of Set 3 | malpura
# Processing Record 6 of Set 3 | te anau
# Processing Record 7 of Set 3 | udachnyy
# Processing Record 8 of Set 3 | ouallam
# Processing Record 9 of Set 3 | airai
# Processing Record 10 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 12 of Set 3 | rio gallegos
# Processing Record 13 of Set 3 | severo-kurilsk
# Processing Record 14 of Set 3 | kupang
# Processing Record 15 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 3 | cidreira
# Processing Record 17 of Set 3 | saint-francois
# Processing Record 18 of Set 3 | eureka
# Processing Record 19 of Set 3 | saldanha
# Processing Record 20 of Set 3 | mackay
# Processing Record 21 of Set 3 | caravelas
# Processing Record 22 of Set 3 | ribeira grande
# Processing Record 23 of Set 3 | arraial do cabo
# Processing Record 24 of Set 3 | provideniya
# Processing Record 25 of Set 3 | yellowknife
# Processing Record 26 of Set 3 | lovrin
# Processing Record 27 of Set 3 | qaqortoq
# Processing Record 28 of Set 3 | tiksi
# Processing Record 29 of Set 3 | lavrentiya
# Processing Record 30 of Set 3 | champerico
# Processing Record 31 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 3 | samokov
# Processing Record 33 of Set 3 | barrow
# Processing Record 34 of Set 3 | ust-nera
# Processing Record 35 of Set 3 | cayenne
# Processing Record 36 of Set 3 | chuy
# Processing Record 37 of Set 3 | camabatela
# Processing Record 38 of Set 3 | muisne
# Processing Record 39 of Set 3 | orel-izumrud
# Processing Record 40 of Set 3 | okha
# Processing Record 41 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 42 of Set 3 | lichinga
# Processing Record 43 of Set 3 | port macquarie
# Processing Record 44 of Set 3 | laguna
# Processing Record 45 of Set 3 | garden city
# Processing Record 46 of Set 3 | narsaq
# Processing Record 47 of Set 3 | qingdao
# Processing Record 48 of Set 3 | kununurra
# Processing Record 49 of Set 3 | kirakira
# Processing Record 50 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 4 | osa
# Processing Record 2 of Set 4 | namie
# Processing Record 3 of Set 4 | samarai
# Processing Record 4 of Set 4 | zhigansk
# Processing Record 5 of Set 4 | sorland
# Processing Record 6 of Set 4 | torbay
# Processing Record 7 of Set 4 | lander
# Processing Record 8 of Set 4 | dalvik
# Processing Record 9 of Set 4 | pundaguitan
# Processing Record 10 of Set 4 | naples
# Processing Record 11 of Set 4 | puerto carreno
# Processing Record 12 of Set 4 | tumut
# Processing Record 13 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 4 | nabire
# Processing Record 15 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 16 of Set 4 | broome
# Processing Record 17 of Set 4 | faya
# Processing Record 18 of Set 4 | comodoro rivadavia
# Processing Record 19 of Set 4 | ucluelet
# Processing Record 20 of Set 4 | clyde river
# Processing Record 21 of Set 4 | khorixas
# Processing Record 22 of Set 4 | port hedland
# Processing Record 23 of Set 4 | hailar
# Processing Record 24 of Set 4 | collie
# Processing Record 25 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 26 of Set 4 | longyearbyen
# Processing Record 27 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 4 | el faiyum
# City not found. Skipping...
# Processing Record 29 of Set 4 | doha
# Processing Record 30 of Set 4 | tornio
# Processing Record 31 of Set 4 | moussoro
# Processing Record 32 of Set 4 | sioux lookout
# Processing Record 33 of Set 4 | saint anthony
# Processing Record 34 of Set 4 | zastron
# Processing Record 35 of Set 4 | conceicao do araguaia
# Processing Record 36 of Set 4 | sakaiminato
# Processing Record 37 of Set 4 | russell
# Processing Record 38 of Set 4 | sechura
# Processing Record 39 of Set 4 | cururupu
# Processing Record 40 of Set 4 | faanui
# Processing Record 41 of Set 4 | saint-pierre
# Processing Record 42 of Set 4 | edd
# Processing Record 43 of Set 4 | sambava
# Processing Record 44 of Set 4 | olafsvik
# Processing Record 45 of Set 4 | gidole
# Processing Record 46 of Set 4 | ilulissat
# Processing Record 47 of Set 4 | mahebourg
# Processing Record 48 of Set 4 | leningradskiy
# Processing Record 49 of Set 4 | eenhana
# Processing Record 50 of Set 4 | muros
# Processing Record 1 of Set 5 | hornepayne
# Processing Record 2 of Set 5 | barbastro
# Processing Record 3 of Set 5 | khormuj
# City not found. Skipping...
# Processing Record 4 of Set 5 | san felipe
# Processing Record 5 of Set 5 | hervey bay
# Processing Record 6 of Set 5 | prince rupert
# Processing Record 7 of Set 5 | oktyabrskiy
# Processing Record 8 of Set 5 | ahipara
# Processing Record 9 of Set 5 | murgab
# Processing Record 10 of Set 5 | gazanjyk
# Processing Record 11 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 5 | itoman
# Processing Record 13 of Set 5 | swan river
# Processing Record 14 of Set 5 | jumla
# Processing Record 15 of Set 5 | brigantine
# Processing Record 16 of Set 5 | san policarpo
# Processing Record 17 of Set 5 | hay river
# Processing Record 18 of Set 5 | avarua
# Processing Record 19 of Set 5 | aykhal
# Processing Record 20 of Set 5 | ceres
# Processing Record 21 of Set 5 | itarema
# Processing Record 22 of Set 5 | turochak
# Processing Record 23 of Set 5 | winnemucca
# Processing Record 24 of Set 5 | dunedin
# Processing Record 25 of Set 5 | kruisfontein
# Processing Record 26 of Set 5 | ozorkow
# Processing Record 27 of Set 5 | veraval
# Processing Record 28 of Set 5 | roma
# Processing Record 29 of Set 5 | yelizovo
# Processing Record 30 of Set 5 | porto velho
# Processing Record 31 of Set 5 | raahe
# Processing Record 32 of Set 5 | muhos
# Processing Record 33 of Set 5 | kapaa
# Processing Record 34 of Set 5 | mizan teferi
# Processing Record 35 of Set 5 | marseille
# Processing Record 36 of Set 5 | flinders
# Processing Record 37 of Set 5 | castro
# Processing Record 38 of Set 5 | sheltozero
# Processing Record 39 of Set 5 | preobrazheniye
# Processing Record 40 of Set 5 | souillac
# Processing Record 41 of Set 5 | namanga
# Processing Record 42 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 43 of Set 5 | leh
# Processing Record 44 of Set 5 | kashiwazaki
# Processing Record 45 of Set 5 | merauke
# Processing Record 46 of Set 5 | houma
# Processing Record 47 of Set 5 | aklavik
# Processing Record 48 of Set 5 | cedral
# Processing Record 49 of Set 5 | orange
# Processing Record 50 of Set 5 | saqqez
# Processing Record 1 of Set 6 | salto
# Processing Record 2 of Set 6 | kavaratti
# Processing Record 3 of Set 6 | buraydah
# Processing Record 4 of Set 6 | port lincoln
# Processing Record 5 of Set 6 | luanda
# Processing Record 6 of Set 6 | takoradi
# Processing Record 7 of Set 6 | bosaso
# Processing Record 8 of Set 6 | acapulco
# Processing Record 9 of Set 6 | tucuman
# Processing Record 10 of Set 6 | gandajika
# Processing Record 11 of Set 6 | gat
# Processing Record 12 of Set 6 | sinnamary
# Processing Record 13 of Set 6 | price
# Processing Record 14 of Set 6 | half moon bay
# Processing Record 15 of Set 6 | saskylakh
# Processing Record 16 of Set 6 | georgetown
# Processing Record 17 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 6 | christchurch
# Processing Record 19 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 6 | la serena
# Processing Record 21 of Set 6 | baijiantan
# Processing Record 22 of Set 6 | marystown
# Processing Record 23 of Set 6 | ust-kuyga
# Processing Record 24 of Set 6 | zeya
# Processing Record 25 of Set 6 | lensk
# Processing Record 26 of Set 6 | hamilton
# Processing Record 27 of Set 6 | alice springs
# Processing Record 28 of Set 6 | tautira
# Processing Record 29 of Set 6 | bambous virieux
# Processing Record 30 of Set 6 | solnechnyy
# Processing Record 31 of Set 6 | klaksvik
# Processing Record 32 of Set 6 | poso
# Processing Record 33 of Set 6 | vung tau
# Processing Record 34 of Set 6 | east london
# Processing Record 35 of Set 6 | lodingen
# Processing Record 36 of Set 6 | belaya gora
# Processing Record 37 of Set 6 | kyra
# Processing Record 38 of Set 6 | hirara
# Processing Record 39 of Set 6 | kosa
# Processing Record 40 of Set 6 | bima
# Processing Record 41 of Set 6 | nagato
# Processing Record 42 of Set 6 | marsa matruh
# Processing Record 43 of Set 6 | mehamn
# Processing Record 44 of Set 6 | kismayo
# Processing Record 45 of Set 6 | naryan-mar
# Processing Record 46 of Set 6 | kaitangata
# Processing Record 47 of Set 6 | salamanca
# Processing Record 48 of Set 6 | cardston
# Processing Record 49 of Set 6 | khasan
# Processing Record 50 of Set 6 | vila franca do campo
# Processing Record 1 of Set 7 | nanortalik
# Processing Record 2 of Set 7 | khudumelapye
# Processing Record 3 of Set 7 | pevek
# Processing Record 4 of Set 7 | svetlyy
# Processing Record 5 of Set 7 | vrangel
# Processing Record 6 of Set 7 | viedma
# Processing Record 7 of Set 7 | meiringen
# Processing Record 8 of Set 7 | bengkulu
# Processing Record 9 of Set 7 | cabo rojo
# Processing Record 10 of Set 7 | port hardy
# Processing Record 11 of Set 7 | the pas
# Processing Record 12 of Set 7 | ketchikan
# Processing Record 13 of Set 7 | byron bay
# Processing Record 14 of Set 7 | victoria
# Processing Record 15 of Set 7 | culaman
# Processing Record 16 of Set 7 | nuqui
# Processing Record 17 of Set 7 | ajdabiya
# Processing Record 18 of Set 7 | perth
# Processing Record 19 of Set 7 | vestmannaeyjar
# Processing Record 20 of Set 7 | ratnagiri
# Processing Record 21 of Set 7 | vila velha
# Processing Record 22 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 7 | anadyr
# Processing Record 24 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 7 | praia
# Processing Record 26 of Set 7 | kalmunai
# Processing Record 27 of Set 7 | axim
# Processing Record 28 of Set 7 | wadi musa
# Processing Record 29 of Set 7 | imbituba
# Processing Record 30 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 32 of Set 7 | hasaki
# Processing Record 33 of Set 7 | pokhara
# Processing Record 34 of Set 7 | balkanabat
# Processing Record 35 of Set 7 | manzanillo
# Processing Record 36 of Set 7 | port-cartier
# Processing Record 37 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 38 of Set 7 | isangel
# Processing Record 39 of Set 7 | sovetskiy
# Processing Record 40 of Set 7 | whitecourt
# Processing Record 41 of Set 7 | forestville
# Processing Record 42 of Set 7 | senanga
# Processing Record 43 of Set 7 | kaniama
# Processing Record 44 of Set 7 | omaruru
# Processing Record 45 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 7 | dharchula
# Processing Record 47 of Set 7 | saint-augustin
# Processing Record 48 of Set 7 | kouroussa
# Processing Record 49 of Set 7 | toora-khem
# Processing Record 50 of Set 7 | san patricio
# Processing Record 1 of Set 8 | rio claro
# Processing Record 2 of Set 8 | cockburn town
# Processing Record 3 of Set 8 | rafsanjan
# Processing Record 4 of Set 8 | hurghada
# Processing Record 5 of Set 8 | bousso
# Processing Record 6 of Set 8 | goderich
# Processing Record 7 of Set 8 | srednekolymsk
# Processing Record 8 of Set 8 | panjab
# Processing Record 9 of Set 8 | ancud
# Processing Record 10 of Set 8 | chengzihe
# Processing Record 11 of Set 8 | athabasca
# Processing Record 12 of Set 8 | san cristobal
# Processing Record 13 of Set 8 | manggar
# Processing Record 14 of Set 8 | shimoda
# Processing Record 15 of Set 8 | teshie
# Processing Record 16 of Set 8 | sao filipe
# Processing Record 17 of Set 8 | tessalit
# Processing Record 18 of Set 8 | quatre cocos
# Processing Record 19 of Set 8 | midland
# Processing Record 20 of Set 8 | atar
# Processing Record 21 of Set 8 | burica
# City not found. Skipping...
# Processing Record 22 of Set 8 | promyshlennyy
# Processing Record 23 of Set 8 | mpongwe
# Processing Record 24 of Set 8 | birao
# Processing Record 25 of Set 8 | bodden town
# Processing Record 26 of Set 8 | warri
# Processing Record 27 of Set 8 | cape town
# Processing Record 28 of Set 8 | zwettl
# Processing Record 29 of Set 8 | shenjiamen
# Processing Record 30 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 8 | adre
# Processing Record 32 of Set 8 | kongsvinger
# Processing Record 33 of Set 8 | ambanja
# Processing Record 34 of Set 8 | maceio
# Processing Record 35 of Set 8 | dukat
# Processing Record 36 of Set 8 | san vicente
# Processing Record 37 of Set 8 | nyimba
# Processing Record 38 of Set 8 | puerto escondido
# Processing Record 39 of Set 8 | nove mesto na morave
# Processing Record 40 of Set 8 | bontang
# Processing Record 41 of Set 8 | abu jubayhah
# City not found. Skipping...
# Processing Record 42 of Set 8 | superior
# Processing Record 43 of Set 8 | lebu
# Processing Record 44 of Set 8 | ponta delgada
# Processing Record 45 of Set 8 | rocha
# Processing Record 46 of Set 8 | mae hong son
# Processing Record 47 of Set 8 | kvam
# Processing Record 48 of Set 8 | lancaster
# Processing Record 49 of Set 8 | srivardhan
# Processing Record 50 of Set 8 | nishihara
# Processing Record 1 of Set 9 | west wendover
# Processing Record 2 of Set 9 | agirish
# Processing Record 3 of Set 9 | tomatlan
# Processing Record 4 of Set 9 | conselheiro pena
# Processing Record 5 of Set 9 | lampang
# Processing Record 6 of Set 9 | moerai
# Processing Record 7 of Set 9 | kondinskoye
# Processing Record 8 of Set 9 | pangnirtung
# Processing Record 9 of Set 9 | yulara
# Processing Record 10 of Set 9 | guangyuan
# Processing Record 11 of Set 9 | weyburn
# Processing Record 12 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 13 of Set 9 | codrington
# Processing Record 14 of Set 9 | makhachkala
# Processing Record 15 of Set 9 | geraldton
# Processing Record 16 of Set 9 | alpoyeca
# Processing Record 17 of Set 9 | umea
# Processing Record 18 of Set 9 | broken hill
# Processing Record 19 of Set 9 | den helder
# Processing Record 20 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 21 of Set 9 | vanavara
# Processing Record 22 of Set 9 | dondo
# Processing Record 23 of Set 9 | saint george
# Processing Record 24 of Set 9 | north platte
# Processing Record 25 of Set 9 | requena
# Processing Record 26 of Set 9 | morgan city
# Processing Record 27 of Set 9 | basco
# Processing Record 28 of Set 9 | erzin
# Processing Record 29 of Set 9 | mantua
# Processing Record 30 of Set 9 | cheremukhovo
# Processing Record 31 of Set 9 | nyrob
# Processing Record 32 of Set 9 | turba
# Processing Record 33 of Set 9 | calama
# Processing Record 34 of Set 9 | anloga
# Processing Record 35 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 9 | bow island
# Processing Record 37 of Set 9 | shelbyville
# Processing Record 38 of Set 9 | beloha
# Processing Record 39 of Set 9 | asyut
# Processing Record 40 of Set 9 | soubre
# Processing Record 41 of Set 9 | jalu
# Processing Record 42 of Set 9 | mahibadhoo
# Processing Record 43 of Set 9 | marabba
# Processing Record 44 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 45 of Set 9 | fairbanks
# Processing Record 46 of Set 9 | manono
# Processing Record 47 of Set 9 | korla
# Processing Record 48 of Set 9 | tuatapere
# Processing Record 49 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 9 | hondo
# Processing Record 1 of Set 10 | bindura
# Processing Record 2 of Set 10 | warin chamrap
# Processing Record 3 of Set 10 | banikoara
# Processing Record 4 of Set 10 | nouadhibou
# Processing Record 5 of Set 10 | kavieng
# Processing Record 6 of Set 10 | kattivakkam
# Processing Record 7 of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record 8 of Set 10 | pemangkat
# Processing Record 9 of Set 10 | koutsouras
# Processing Record 10 of Set 10 | diego de almagro
# Processing Record 11 of Set 10 | padang
# Processing Record 12 of Set 10 | tazovskiy
# Processing Record 13 of Set 10 | ust-omchug
# Processing Record 14 of Set 10 | lac du bonnet
# Processing Record 15 of Set 10 | aberfeldy
# Processing Record 16 of Set 10 | nekhayevskiy
# Processing Record 17 of Set 10 | petropavl
# Processing Record 18 of Set 10 | asau
# Processing Record 19 of Set 10 | betioky
# Processing Record 20 of Set 10 | manhattan
# Processing Record 21 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 22 of Set 10 | kloulklubed
# Processing Record 23 of Set 10 | nioro
# Processing Record 24 of Set 10 | pochutla
# Processing Record 25 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 10 | fukue
# Processing Record 27 of Set 10 | kindia
# Processing Record 28 of Set 10 | pangkalanbuun
# Processing Record 29 of Set 10 | killybegs
# Processing Record 30 of Set 10 | hambantota
# Processing Record 31 of Set 10 | anchorage
# Processing Record 32 of Set 10 | bundaberg
# Processing Record 33 of Set 10 | nemuro
# Processing Record 34 of Set 10 | nuevo progreso
# Processing Record 35 of Set 10 | auki
# Processing Record 36 of Set 10 | amuntai
# Processing Record 37 of Set 10 | lukovetskiy
# Processing Record 38 of Set 10 | seymchan
# Processing Record 39 of Set 10 | dosso
# Processing Record 40 of Set 10 | kahului
# Processing Record 41 of Set 10 | cabo san lucas
# Processing Record 42 of Set 10 | pontianak
# Processing Record 43 of Set 10 | fortuna
# Processing Record 44 of Set 10 | husavik
# Processing Record 45 of Set 10 | catia la mar
# Processing Record 46 of Set 10 | san quintin
# Processing Record 47 of Set 10 | namibe
# Processing Record 48 of Set 10 | tungkang
# City not found. Skipping...
# Processing Record 49 of Set 10 | mount isa
# Processing Record 50 of Set 10 | tambacounda
# Processing Record 1 of Set 11 | upington
# Processing Record 2 of Set 11 | imeni poliny osipenko
# Processing Record 3 of Set 11 | sobolevo
# Processing Record 4 of Set 11 | gore
# Processing Record 5 of Set 11 | shuangcheng
# Processing Record 6 of Set 11 | nome
# Processing Record 7 of Set 11 | marawi
# Processing Record 8 of Set 11 | agaro
# Processing Record 9 of Set 11 | manavalakurichi
# Processing Record 10 of Set 11 | zhuanghe
# Processing Record 11 of Set 11 | kariba
# Processing Record 12 of Set 11 | high level
# Processing Record 13 of Set 11 | quang ngai
# Processing Record 14 of Set 11 | palauig
# Processing Record 15 of Set 11 | katsuura
# Processing Record 16 of Set 11 | pilar
# Processing Record 17 of Set 11 | sydney
# Processing Record 18 of Set 11 | sundarnagar
# Processing Record 19 of Set 11 | monte alegre
# Processing Record 20 of Set 11 | gold coast
# Processing Record 21 of Set 11 | igrim
# Processing Record 22 of Set 11 | barela
# Processing Record 23 of Set 11 | maneadero
# Processing Record 24 of Set 11 | martinsburg
# Processing Record 25 of Set 11 | makarov
# Processing Record 26 of Set 11 | tokzar
# City not found. Skipping...
# Processing Record 27 of Set 11 | lahij
# Processing Record 28 of Set 11 | mtwara
# Processing Record 29 of Set 11 | espinosa
# Processing Record 30 of Set 11 | veracruz
# Processing Record 31 of Set 11 | boa viagem
# Processing Record 32 of Set 11 | meinung
# City not found. Skipping...
# Processing Record 33 of Set 11 | nantucket
# Processing Record 34 of Set 11 | ambulu
# Processing Record 35 of Set 11 | talara
# Processing Record 36 of Set 11 | egvekinot
# Processing Record 37 of Set 11 | achit
# Processing Record 38 of Set 11 | luwuk
# Processing Record 39 of Set 11 | butajira
# Processing Record 40 of Set 11 | gannan
# Processing Record 41 of Set 11 | lahaina
# Processing Record 42 of Set 11 | pontalina
# Processing Record 43 of Set 11 | teterow
# Processing Record 44 of Set 11 | north bend
# Processing Record 45 of Set 11 | nyagan
# Processing Record 46 of Set 11 | ler
# Processing Record 47 of Set 11 | sayyan
# Processing Record 48 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 49 of Set 11 | chapais
# Processing Record 50 of Set 11 | nyurba
# Processing Record 1 of Set 12 | puerto del rosario
# Processing Record 2 of Set 12 | northam
# Processing Record 3 of Set 12 | nossa senhora das dores
# Processing Record 4 of Set 12 | porto murtinho
# Processing Record 5 of Set 12 | charlestown
# Processing Record 6 of Set 12 | falmouth
# Processing Record 7 of Set 12 | adrar
# Processing Record 8 of Set 12 | amalfi
# Processing Record 9 of Set 12 | jinchengjiang
# City not found. Skipping...
# Processing Record 10 of Set 12 | port blair
# Processing Record 11 of Set 12 | gao
# Processing Record 12 of Set 12 | turukhansk
# Processing Record 13 of Set 12 | camacha
# Processing Record 14 of Set 12 | marsh harbour
# Processing Record 15 of Set 12 | lazaro cardenas
# Processing Record 16 of Set 12 | beira
# Processing Record 17 of Set 12 | ivanava
# Processing Record 18 of Set 12 | barra do bugres
# Processing Record 19 of Set 12 | nurota
# Processing Record 20 of Set 12 | lata
# Processing Record 21 of Set 12 | sondershausen
# Processing Record 22 of Set 12 | montague
# Processing Record 23 of Set 12 | coquimbo
# Processing Record 24 of Set 12 | bushehr
# Processing Record 25 of Set 12 | bati
# Processing Record 26 of Set 12 | labuhan
# Processing Record 27 of Set 12 | kesinga
# Processing Record 28 of Set 12 | kurilsk
# Processing Record 29 of Set 12 | havre
# Processing Record 30 of Set 12 | pingliang
# Processing Record 31 of Set 12 | karwar
# Processing Record 32 of Set 12 | acajutla
# Processing Record 33 of Set 12 | kendari
# Processing Record 34 of Set 12 | marquette
# Processing Record 35 of Set 12 | omsukchan
# Processing Record 36 of Set 12 | bend
# Processing Record 37 of Set 12 | fuyang
# Processing Record 38 of Set 12 | coahuayana
# Processing Record 39 of Set 12 | saint-joseph
# Processing Record 40 of Set 12 | zhuhai
# Processing Record 41 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 42 of Set 12 | tilichiki
# Processing Record 43 of Set 12 | nueva granada
# Processing Record 44 of Set 12 | richards bay
# Processing Record 45 of Set 12 | maragogi
# Processing Record 46 of Set 12 | atka
# City not found. Skipping...
# Processing Record 47 of Set 12 | nampula
# Processing Record 48 of Set 12 | san isidro
# Processing Record 49 of Set 12 | mackenzie
# Processing Record 50 of Set 12 | kipit
# Processing Record 1 of Set 13 | sorong
# Processing Record 2 of Set 13 | charters towers
# Processing Record 3 of Set 13 | mandalgovi
# Processing Record 4 of Set 13 | praia da vitoria
# Processing Record 5 of Set 13 | ballina
# Processing Record 6 of Set 13 | chifeng
# Processing Record 7 of Set 13 | paita
# Processing Record 8 of Set 13 | anisoc
# Processing Record 9 of Set 13 | muswellbrook
# Processing Record 10 of Set 13 | navalmoral de la mata
# Processing Record 11 of Set 13 | koshurnikovo
# Processing Record 12 of Set 13 | koutiala
# Processing Record 13 of Set 13 | george
# Processing Record 14 of Set 13 | seoul
# Processing Record 15 of Set 13 | bathsheba
# Processing Record 16 of Set 13 | maloy
# Processing Record 17 of Set 13 | bassar
# Processing Record 18 of Set 13 | prado
# Processing Record 19 of Set 13 | cedar city
# Processing Record 20 of Set 13 | karamay
# City not found. Skipping...
# Processing Record 21 of Set 13 | narrabri
# Processing Record 22 of Set 13 | qandala
# Processing Record 23 of Set 13 | reconquista
# Processing Record 24 of Set 13 | andenes
# Processing Record 25 of Set 13 | gravdal
# Processing Record 26 of Set 13 | denpasar
# Processing Record 27 of Set 13 | cuamba
# Processing Record 28 of Set 13 | gunjur
# Processing Record 29 of Set 13 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 13 | bandarbeyla
# Processing Record 31 of Set 13 | strai
# Processing Record 32 of Set 13 | manado
# Processing Record 33 of Set 13 | mega
# Processing Record 34 of Set 13 | whitehorse
# Processing Record 35 of Set 13 | ardatov
# Processing Record 36 of Set 13 | xichang
# Processing Record 37 of Set 13 | hannibal
# Processing Record 38 of Set 13 | tatarastii de sus
# City not found. Skipping...
# Processing Record 39 of Set 13 | vila do maio
# Processing Record 40 of Set 13 | pangai
# Processing Record 41 of Set 13 | montepuez
# Processing Record 42 of Set 13 | hare bay
# Processing Record 43 of Set 13 | bandiagara
# Processing Record 44 of Set 13 | bay roberts
# Processing Record 45 of Set 13 | gamba
# Processing Record 46 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 47 of Set 13 | rio grande
# Processing Record 48 of Set 13 | havoysund
# Processing Record 49 of Set 13 | talcher
# Processing Record 50 of Set 13 | ustye
# Processing Record 1 of Set 14 | terrace
# Processing Record 2 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 3 of Set 14 | tura
# Processing Record 4 of Set 14 | puerto suarez
# Processing Record 5 of Set 14 | sisimiut
# Processing Record 6 of Set 14 | havre-saint-pierre
# Processing Record 7 of Set 14 | karanpura
# Processing Record 8 of Set 14 | suntar
# Processing Record 9 of Set 14 | goksun
# Processing Record 10 of Set 14 | miranda
# Processing Record 11 of Set 14 | reoti
# Processing Record 12 of Set 14 | maniitsoq
# Processing Record 13 of Set 14 | lagoa
# Processing Record 14 of Set 14 | poya
# Processing Record 15 of Set 14 | santa rosa
# Processing Record 16 of Set 14 | belmonte
# Processing Record 17 of Set 14 | kargasok
# Processing Record 18 of Set 14 | touros
# Processing Record 19 of Set 14 | machiques
# Processing Record 20 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 21 of Set 14 | deputatskiy
# Processing Record 22 of Set 14 | ilembula
# Processing Record 23 of Set 14 | carballo
# Processing Record 24 of Set 14 | topolobampo
# Processing Record 25 of Set 14 | sarkand
# Processing Record 26 of Set 14 | rockland
# Processing Record 27 of Set 14 | jamame
# Processing Record 28 of Set 14 | kandi
# Processing Record 29 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 30 of Set 14 | aksu
# Processing Record 31 of Set 14 | tual
# Processing Record 32 of Set 14 | taua
# Processing Record 33 of Set 14 | inta
# Processing Record 34 of Set 14 | surt
# Processing Record 35 of Set 14 | meulaboh
# Processing Record 36 of Set 14 | oistins
# Processing Record 37 of Set 14 | hobyo
# Processing Record 38 of Set 14 | burnie
# Processing Record 39 of Set 14 | kyabe
# Processing Record 40 of Set 14 | vardo
# Processing Record 41 of Set 14 | wahiawa
# Processing Record 42 of Set 14 | sassandra
# Processing Record 43 of Set 14 | zaraza
# Processing Record 44 of Set 14 | chikoy
# City not found. Skipping...
# Processing Record 45 of Set 14 | kinatakutan
# Processing Record 46 of Set 14 | hualmay
# Processing Record 47 of Set 14 | porto novo
# Processing Record 48 of Set 14 | riachao das neves
# Processing Record 49 of Set 14 | riyadh
# Processing Record 50 of Set 14 | campina verde
# Processing Record 1 of Set 15 | santa cruz
# Processing Record 2 of Set 15 | boa vista
# Processing Record 3 of Set 15 | malanje
# Processing Record 4 of Set 15 | twentynine palms
# Processing Record 5 of Set 15 | ovre ardal
# Processing Record 6 of Set 15 | springdale
# Processing Record 7 of Set 15 | borovoy
# Processing Record 8 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 15 | maghama
# City not found. Skipping...
# Processing Record 10 of Set 15 | santiago
# Processing Record 11 of Set 15 | garissa
# Processing Record 12 of Set 15 | kitimat
# Processing Record 13 of Set 15 | taupo
# Processing Record 14 of Set 15 | manta
# Processing Record 15 of Set 15 | banda aceh
# Processing Record 16 of Set 15 | port-gentil
# Processing Record 17 of Set 15 | palembang
# Processing Record 18 of Set 15 | cap malheureux
# Processing Record 19 of Set 15 | mabaruma
# Processing Record 20 of Set 15 | zunyi
# Processing Record 21 of Set 15 | teguldet
# Processing Record 22 of Set 15 | seversk
# Processing Record 23 of Set 15 | berekum
# Processing Record 24 of Set 15 | show low
# Processing Record 25 of Set 15 | cutervo
# Processing Record 26 of Set 15 | san jose
# Processing Record 27 of Set 15 | smithers
# Processing Record 28 of Set 15 | anar darreh
# City not found. Skipping...
# Processing Record 29 of Set 15 | bangangte
# Processing Record 30 of Set 15 | port hueneme
# Processing Record 31 of Set 15 | mafinga
# Processing Record 32 of Set 15 | pincher creek
# Processing Record 33 of Set 15 | leavenworth
# Processing Record 34 of Set 15 | martinopolis
# Processing Record 35 of Set 15 | skagastrond
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 670

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Thompson      CA  55.7435  -97.8558     60.96        77          75
# 1        Huilong      CN  31.8111  121.6550     70.93        68           3
# 2        Ushuaia      AR -54.8000  -68.3000     53.26        35           0
# 3  Pacific Grove      US  36.6177 -121.9166     71.82        86           0
# 4           Elko      US  41.0002 -115.5012     78.64        12           0
# 5         Owando      CG  -0.4819   15.8999     71.69        96          90
# 6           Jadu      LY  31.9530   12.0261     82.15        25           0
# 7    Fort Nelson      CA  58.8053 -122.7002     58.59        47          75
# 8   Ponta Do Sol      PT  32.6667  -17.1000     74.03        91          68
# 9        Rikitea      PF -23.1203 -134.9692     72.52        78          26
#
#    Wind Speed Current Description
# 0        4.61       broken clouds
# 1       14.58           clear sky
# 2        1.14           clear sky
# 3       11.50           clear sky
# 4       15.01           clear sky
# 5        3.09     overcast clouds
# 6        3.65           clear sky
# 7        8.05       broken clouds
# 8        2.37       broken clouds
# 9       15.99          light rain

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
